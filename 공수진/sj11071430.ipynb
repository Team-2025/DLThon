# %%
# !conda install -y -c conda-forge openjdk=11 jpype1
# !pip install konlpy==0.6.0
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - jpype1
#     - openjdk=11
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.14            |       hb9d3cd8_0         553 KB  conda-forge
#     ca-certificates-2025.10.5  |       hbd8a1cb_0         152 KB  conda-forge
#     cairo-1.18.4               |       h3394656_0         955 KB  conda-forge
#     certifi-2025.10.5          |     pyhd8ed1ab_0         156 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |       hc364b38_1           4 KB  conda-forge
#     graphite2-1.3.14           |       hecca717_2          97 KB  conda-forge
#     harfbuzz-11.2.1            |       h3beb420_0         1.7 MB  conda-forge
#     jpype1-1.6.0               |  py312hd9148b4_1         459 KB  conda-forge
#     libcups-2.3.3              |       hb8b1518_5         4.3 MB  conda-forge
#     libglib-2.86.0             |       h1fed272_0         3.8 MB  conda-forge
#     openjdk-11.0.27            |       h5ddf6bc_0       164.0 MB  conda-forge
#     openssl-3.5.4              |       h26f9b46_0         3.0 MB  conda-forge
#     pcre2-10.46                |       h1321c63_0         1.2 MB  conda-forge
#     pixman-0.46.4              |       h54a6638_1         440 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.6           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.12         |       h4f16b4b_0         816 KB  conda-forge
#     xorg-libxext-1.3.6         |       hb9d3cd8_0          49 KB  conda-forge
#     xorg-libxfixes-6.0.2       |       hb03c661_0          20 KB  conda-forge
#     xorg-libxi-1.8.2           |       hb9d3cd8_0          46 KB  conda-forge
#     xorg-libxrandr-1.5.4       |       hb9d3cd8_0          29 KB  conda-forge
#     xorg-libxrender-0.9.12     |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxt-1.3.1           |       hb9d3cd8_0         371 KB  conda-forge
#     xorg-libxtst-1.2.5         |       hb9d3cd8_3          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       185.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.14-hb9d3cd8_0
#   cairo              conda-forge/linux-64::cairo-1.18.4-h3394656_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-hc364b38_1
#   graphite2          conda-forge/linux-64::graphite2-1.3.14-hecca717_2
#   harfbuzz           conda-forge/linux-64::harfbuzz-11.2.1-h3beb420_0
#   jpype1             conda-forge/linux-64::jpype1-1.6.0-py312hd9148b4_1
#   libcups            conda-forge/linux-64::libcups-2.3.3-hb8b1518_5
#   libglib            conda-forge/linux-64::libglib-2.86.0-h1fed272_0
#   openjdk            conda-forge/linux-64::openjdk-11.0.27-h5ddf6bc_0
#   pcre2              conda-forge/linux-64::pcre2-10.46-h1321c63_0
#   pixman             conda-forge/linux-64::pixman-0.46.4-h54a6638_1
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.6-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.12-h4f16b4b_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.6-hb9d3cd8_0
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-6.0.2-hb03c661_0
#   xorg-libxi         conda-forge/linux-64::xorg-libxi-1.8.2-hb9d3cd8_0
#   xorg-libxrandr     conda-forge/linux-64::xorg-libxrandr-1.5.4-hb9d3cd8_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.12-hb9d3cd8_0
#   xorg-libxt         conda-forge/linux-64::xorg-libxt-1.3.1-hb9d3cd8_0
#   xorg-libxtst       conda-forge/linux-64::xorg-libxtst-1.2.5-hb9d3cd8_3
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2025.6.15-hbd8a1cb_0 --> 2025.10.5-hbd8a1cb_0
#   certifi                            2025.6.15-pyhd8ed1ab_0 --> 2025.10.5-pyhd8ed1ab_0
#   openssl                                  3.5.0-h7b32b05_1 --> 3.5.4-h26f9b46_0
#
#
#
# Downloading and Extracting Packages:
# openjdk-11.0.27      | 164.0 MB  |                                       |   0%
# libcups-2.3.3        | 4.3 MB    |                                       |   0%
#
# libglib-2.86.0       | 3.8 MB    |                                       |   0%
#
#
# openssl-3.5.4        | 3.0 MB    |                                       |   0%
#
#
#
# harfbuzz-11.2.1      | 1.7 MB    |                                       |   0%
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |                                       |   0%
#
#
#
#
#
# pcre2-10.46          | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
# cairo-1.18.4         | 955 KB    |                                       |   0%
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# alsa-lib-1.2.14      | 553 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# jpype1-1.6.0         | 459 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 440 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxt-1.3.1     | 371 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.15.0    | 259 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.10.5    | 156 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# graphite2-1.3.14     | 97 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-inconsolata | 94 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libice-1.1.2    | 57 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxext-1.3.6   | 49 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxi-1.8.2     | 46 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | 2                                     |   1% [A
#
#
# openssl-3.5.4        | 3.0 MB    | #############6                        |  37%
#
# libglib-2.86.0       | 3.8 MB    | 1                                     |   0%
#
#
#
# harfbuzz-11.2.1      | 1.7 MB    | ######6                               |  18%
# libcups-2.3.3        | 4.3 MB    | 1                                     |   0%
#
#
#
# openjdk-11.0.27      | 164.0 MB  | #                                     |   3%
#
# libglib-2.86.0       | 3.8 MB    | #############################2        |  79%
# libcups-2.3.3        | 4.3 MB    | ############################1         |  76%
#
#
# openssl-3.5.4        | 3.0 MB    | ##################################### | 100%
#
#
# openssl-3.5.4        | 3.0 MB    | ##################################### | 100%
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | #8                                    |   5%
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
# pcre2-10.46          | 1.2 MB    | ##################################### | 100%
#
# libglib-2.86.0       | 3.8 MB    | ##################################### | 100%
#
#
#
#
#
#
# cairo-1.18.4         | 955 KB    | 6                                     |   2%
# openjdk-11.0.27      | 164.0 MB  | ##5                                   |   7%
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
# alsa-lib-1.2.14      | 553 KB    | #                                     |   3%
#
#
#
#
#
#
# cairo-1.18.4         | 955 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
# jpype1-1.6.0         | 459 KB    | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 440 KB    | #3                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxt-1.3.1     | 371 KB    | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
# jpype1-1.6.0         | 459 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 440 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxt-1.3.1     | 371 KB    | ##################################### | 100%
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.10.5    | 156 KB    | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | ###8                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.10.5    | 156 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.15.0    | 259 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# graphite2-1.3.14     | 97 KB     | ######                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# graphite2-1.3.14     | 97 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libice-1.1.2    | 57 KB     | ##########3                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxext-1.3.6   | 49 KB     | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libice-1.1.2    | 57 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxext-1.3.6   | 49 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxi-1.8.2     | 46 KB     | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-inconsolata | 94 KB     | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-inconsolata | 94 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# harfbuzz-11.2.1      | 1.7 MB    | ##################################### | 100%
#
#
#
# harfbuzz-11.2.1      | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | #######8                              |  21% [A
#
#
# openjdk-11.0.27      | 164.0 MB  | ##########                            |  27%
#
#
#
#
#
# pcre2-10.46          | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | ###########1                          |  30%
# openjdk-11.0.27      | 164.0 MB  | ############3                         |  33%
#
#
#
#
#
#
# cairo-1.18.4         | 955 KB    | ##################################### | 100%
#
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | #############5                        |  37%
#
# openjdk-11.0.27      | 164.0 MB  | ##############7                       |  40%
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | ################9                     |  46%
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# alsa-lib-1.2.14      | 553 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | ##################                    |  49%
#
#
#
#
#
#
#
#
#
#
# jpype1-1.6.0         | 459 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# jpype1-1.6.0         | 459 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 440 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 440 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.10.5    | 156 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | ###################2                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxt-1.3.1     | 371 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | ####################3                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# graphite2-1.3.14     | 97 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# graphite2-1.3.14     | 97 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libice-1.1.2    | 57 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libice-1.1.2    | 57 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxi-1.8.2     | 46 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxi-1.8.2     | 46 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxext-1.3.6   | 49 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | #####################4                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.15.0    | 259 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.15.0    | 259 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-inconsolata | 94 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjdk-11.0.27      | 164.0 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Requirement already satisfied: konlpy==0.6.0 in /opt/conda/lib/python3.12/site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /opt/conda/lib/python3.12/site-packages (from konlpy==0.6.0) (1.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /opt/conda/lib/python3.12/site-packages (from konlpy==0.6.0) (6.0.2)
# Requirement already satisfied: numpy>=1.6 in /opt/conda/lib/python3.12/site-packages (from konlpy==0.6.0) (2.2.6)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from JPype1>=0.7.0->konlpy==0.6.0) (25.0)

# %%
# !ls $CONDA_PREFIX/lib/jvm
# Out:
# bin  conf  include  jmods  legal  lib  man

# %%
# !conda install -y -c conda-forge openjdk=11 jpype1
# !pip install -U konlpy
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: \

# %%
import os, sys
java_home = os.path.join(os.environ["CONDA_PREFIX"], "lib", "jvm", "java-11-openjdk")  # 2단계에서 확인한 폴더명으로 변경
os.environ["JAVA_HOME"] = java_home
os.environ["PATH"] += os.pathsep + os.path.join(java_home, "bin")

# %%
# =========================================================
# 1) 라이브러리
# =========================================================
import os, json, math, random
import numpy as np
import pandas as pd
from collections import Counter, defaultdict

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from konlpy.tag import Okt

# 재현성
SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SAVE_DIR = "work/team2025_pt"
os.makedirs(SAVE_DIR, exist_ok=True)

# %%
# =========================================================
# 2) 라벨 인덱싱
# =========================================================
train = pd.read_csv("team2025/merged_train.csv")
labels = sorted(train['class'].unique())
label2id = {c:i for i,c in enumerate(labels)}
id2label = {i:c for c,i in label2id.items()}
train['label'] = train['class'].map(label2id).astype(int)

with open(os.path.join(SAVE_DIR, "label_classes.json"), "w", encoding="utf-8") as f:
    json.dump(id2label, f, ensure_ascii=False, indent=2)

# %%
# =========================================================
# 3) Stratified 8:2 split (수작업)
# =========================================================
def stratified_split_idx(y, test_size=0.2, seed=42):
    rng = np.random.default_rng(seed)
    y = np.asarray(y)
    cls_indices = defaultdict(list)
    for i, yi in enumerate(y):
        cls_indices[int(yi)].append(i)
    train_idx, valid_idx = [], []
    for cls, idxs in cls_indices.items():
        idxs = np.array(idxs)
        rng.shuffle(idxs)
        n_valid = max(1, int(round(len(idxs)*test_size)))
        valid_idx.extend(idxs[:n_valid].tolist())
        train_idx.extend(idxs[n_valid:].tolist())
    rng.shuffle(train_idx); rng.shuffle(valid_idx)
    return np.array(train_idx), np.array(valid_idx)

tr_idx, va_idx = stratified_split_idx(train['label'].values, test_size=0.2, seed=SEED)
tr_df = train.iloc[tr_idx].reset_index(drop=True)
va_df = train.iloc[va_idx].reset_index(drop=True)

# %%
# =========================================================
# 4) OKT 토큰화
# =========================================================
okt = Okt()

def tokenize_okt(text, norm=True, stem=False):
    s = str(text).strip()
    # 필요 시 추가 정규화 로직을 여기에 삽입
    return okt.morphs(s, stem=stem) if not norm else okt.morphs(s, stem=stem)

tr_tokens = [tokenize_okt(s) for s in tr_df['conversation']]
va_tokens = [tokenize_okt(s) for s in va_df['conversation']]
